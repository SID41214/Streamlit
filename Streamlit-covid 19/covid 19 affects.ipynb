# %%
# import numpy as np 
# import pandas as pd 
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

# %%
# pip install --upgrade numpy pandas

# %%
import numpy as np 
import pandas as pd 
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import plotly.graph_objects as go

# %%
# pip install --upgrade numpy pandas matplotlib seaborn plotly

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Copy of covid_affect.csv')

# %%
df.head()
# Out:
#       age  gender          occupation line_of_work  time_bp  time_dp  \
# 0   19-25    Male  Student in College          NaN        7        5
# 1  Dec-18    Male   Student in School          NaN        7       11
# 2   19-25    Male  Student in College          NaN        7        7
# 3   19-25    Male  Student in College          NaN        7        7
# 4   19-25  Female  Student in College          NaN        7        7
#
#    travel_time  easeof_online  home_env  prod_inc  ...  fam_connect  relaxed  \
# 0          0.5              3         3       0.0  ...          1.0     -0.5
# 1          0.5              4         2      -0.5  ...          1.0      1.0
# 2          1.5              2         2       1.0  ...          0.5      0.5
# 3          1.5              3         1       0.0  ...          0.0     -1.0
# 4          1.5              2         2       0.0  ...          0.0      0.5
#
#    self_time  like_hw  dislike_hw                        prefer  \
# ...

# %%
df.tail()
# Out:
#         age  gender            occupation line_of_work  time_bp  time_dp  \
# 1170  40-50  Female          Entrepreneur          NaN        9        9
# 1171  26-32  Female             Homemaker          NaN        5       12
# 1172  26-32    Male  Working Professional  Engineering        9       11
# 1173  26-32    Male  Working Professional  Engineering       11       12
# 1174  40-50    Male  Working Professional  Engineering        5        5
#
#       travel_time  easeof_online  home_env  prod_inc  ...  fam_connect  \
# 1170          0.5              2         1       0.5  ...          0.5
# 1171          0.5              3         5      -0.5  ...          0.0
# 1172          0.5              3         2       0.5  ...          0.5
# 1173          1.5              2         2       0.0  ...         -1.0
# 1174          0.5              2         2       0.5  ...          0.5
#
#       relaxed  self_time  like_hw  dislike_hw                        prefer  \
# ...

# %%
df.shape
# Out:
# (1175, 22)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'occupation', 'line_of_work', 'time_bp', 'time_dp',
#        'travel_time', 'easeof_online', 'home_env', 'prod_inc', 'sleep_bal',
#        'new_skill', 'fam_connect', 'relaxed', 'self_time', 'like_hw',
#        'dislike_hw', 'prefer', 'certaindays_hw', 'Unnamed: 19', 'time_bp.1',
#        'travel+work'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 762

# %%
df.isnull().sum()
# Out:
# age                  0
# gender               0
# occupation           0
# line_of_work       696
# time_bp              0
# time_dp              0
# travel_time          0
# easeof_online        0
# home_env             0
# prod_inc             0
# sleep_bal            0
# new_skill            0
# fam_connect          0
# relaxed              0
# self_time            0
# like_hw              0
# dislike_hw           0
# prefer               0
# certaindays_hw       0
# Unnamed: 19       1175
# time_bp.1            0
# travel+work       1175
# dtype: int64

# %%
df = df.drop(['line_of_work', 'Unnamed: 19', 'travel+work'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1175 non-null   object
#  1   gender          1175 non-null   object
#  2   occupation      1175 non-null   object
#  3   time_bp         1175 non-null   int64
#  4   time_dp         1175 non-null   int64
#  5   travel_time     1175 non-null   float64
#  6   easeof_online   1175 non-null   int64
#  7   home_env        1175 non-null   int64
#  8   prod_inc        1175 non-null   float64
#  9   sleep_bal       1175 non-null   float64
#  10  new_skill       1175 non-null   float64
#  11  fam_connect     1175 non-null   float64
#  12  relaxed         1175 non-null   float64
#  13  self_time       1175 non-null   float64
#  14  like_hw         1175 non-null   int64
#  15  dislike_hw      1175 non-null   int64
#  16  prefer          1175 non-null   object
# ...

# %%
df.describe()
# Out:
#            time_bp      time_dp  travel_time  easeof_online     home_env  \
# count  1175.000000  1175.000000  1175.000000    1175.000000  1175.000000
# mean      7.415319     7.971915     1.027660       2.533617     2.752340
# std       2.005385     2.657007     0.713314       1.267609     1.235799
# min       4.000000     4.000000     0.500000       1.000000     1.000000
# 25%       5.000000     5.000000     0.500000       1.000000     2.000000
# 50%       7.000000     9.000000     0.500000       2.000000     3.000000
# 75%       9.000000     9.000000     1.500000       4.000000     4.000000
# max      12.000000    12.000000     3.000000       5.000000     5.000000
#
#           prod_inc    sleep_bal    new_skill  fam_connect      relaxed  \
# count  1175.000000  1175.000000  1175.000000  1175.000000  1175.000000
# mean      0.008936    -0.108936     0.146809     0.260426     0.035745
# std       0.615083     0.621215     0.643686     0.686825     0.626637
# ...

# %%
df.nunique()
# Out:
# age                7
# gender             3
# occupation         8
# time_bp            6
# time_dp            6
# travel_time        4
# easeof_online      5
# home_env           5
# prod_inc           5
# sleep_bal          5
# new_skill          5
# fam_connect        5
# relaxed            5
# self_time          5
# like_hw           15
# dislike_hw        15
# prefer             2
# certaindays_hw     3
# time_bp.1          6
# dtype: int64

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical Columns:",numerical_columns)

object_columns = df.select_dtypes(include=['object']).columns
print("\nObject Columns:",object_columns)
# Out:
# Numerical Columns: Index(['time_bp', 'time_dp', 'travel_time', 'easeof_online', 'home_env',
#        'prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed',
#        'self_time', 'like_hw', 'dislike_hw', 'time_bp.1'],
#       dtype='object')
#
# Object Columns: Index(['age', 'gender', 'occupation', 'prefer', 'certaindays_hw'], dtype='object')

# %%
for column in numerical_columns:
    unique_values = df[column].unique()
    print(f"{column}: {unique_values}")
# Out:
# time_bp: [ 7  5  9 11  4 12]
# time_dp: [ 5 11  7  4  9 12]
# travel_time: [0.5 1.5 2.5 3. ]
# easeof_online: [3 4 2 1 5]
# home_env: [3 2 1 4 5]
# prod_inc: [ 0.  -0.5  1.  -1.   0.5]
# sleep_bal: [ 0.   0.5  1.  -1.  -0.5]
# new_skill: [ 0.5 -1.   0.   1.  -0.5]
# fam_connect: [ 1.   0.5  0.  -0.5 -1. ]
# relaxed: [-0.5  1.   0.5 -1.   0. ]
# self_time: [-0.5  1.   0.5  0.  -1. ]
# like_hw: [ 100 1111 1100 1010  110 1000 1110   10 1001    1 1011   11  101  111
#  1101]
# dislike_hw: [   1 1110  111 1111 1000 1100 1101  100 1011 1001 1010   10  101   11
#   110]
# time_bp.1: [ 7  5  9 11  4 12]

# %%
for column in object_columns:
    unique_values = df[column].unique()
    print(f"{column}: {unique_values}")
# Out:
# age: ['19-25' 'Dec-18' '33-40' '60+' '26-32' '40-50' '50-60']
# gender: ['Male' 'Female' 'Prefer not to say']
# occupation: ['Student in College' 'Student in School' 'Working Professional'
#  'Entrepreneur' 'Retired/Senior Citizen' 'Homemaker'
#  'Currently Out of Work'
#  'Medical Professional aiding efforts against COVID-19']
# prefer: ['Complete Physical Attendance' 'Work/study from home']
# certaindays_hw: ['Yes' 'No' 'Maybe']

# %%
for column in numerical_columns:
    value_counts = df[column].value_counts()
    print(column,':') 
    print(value_counts)
    print('\n')
# Out:
# time_bp :
# time_bp
# 7     412
# 9     343
# 5     283
# 11     53
# 12     51
# 4      33
# Name: count, dtype: int64
#
#
# time_dp :
# time_dp
# 9     326
# 7     238
# 5     180
# 12    169
# 4     149
# 11    113
# Name: count, dtype: int64
#
#
# travel_time :
# travel_time
# 0.5    699
# 1.5    343
# 2.5    111
# 3.0     22
# Name: count, dtype: int64
#
#
# easeof_online :
# easeof_online
# 1    329
# 2    285
# 4    249
# 3    239
# 5     73
# Name: count, dtype: int64
#
#
# home_env :
# home_env
# 3    327
# 2    309
# 1    215
# 4    200
# 5    124
# Name: count, dtype: int64
#
#
# prod_inc :
# prod_inc
#  0.5    302
#  0.0    295
# -0.5    279
# -1.0    150
#  1.0    149
# Name: count, dtype: int64
#
#
# sleep_bal :
# sleep_bal
# -0.5    313
#  0.5    271
#  0.0    270
# -1.0    214
#  1.0    107
# Name: count, dtype: int64
#
#
# new_skill :
# new_skill
#  0.5    366
# -0.5    249
#  1.0    236
#  0.0    202
# -1.0    122
# Name: count, dtype: int64
#
#
# fam_connect :
# ...

# %%
for column in object_columns:
    value_counts = df[column].value_counts()
    print(column,':') 
    print(value_counts)
    print('\n')
# Out:
# age :
# age
# 19-25     345
# 26-32     261
# 40-50     181
# 50-60     170
# 33-40     102
# Dec-18     74
# 60+        42
# Name: count, dtype: int64
#
#
# gender :
# gender
# Male                 649
# Female               518
# Prefer not to say      8
# Name: count, dtype: int64
#
#
# occupation :
# occupation
# Working Professional                                    479
# Student in College                                      358
# Entrepreneur                                            119
# Homemaker                                                82
# Medical Professional aiding efforts against COVID-19     73
# Currently Out of Work                                    44
# Student in School                                        18
# Retired/Senior Citizen                                    2
# Name: count, dtype: int64
#
#
# prefer :
# prefer
# Complete Physical Attendance    836
# Work/study from home            339
# Name: count, dtype: int64
#
#
# certaindays_hw :
# ...

# %%
df.columns
# Out:
# Index(['age', 'gender', 'occupation', 'time_bp', 'time_dp', 'travel_time',
#        'easeof_online', 'home_env', 'prod_inc', 'sleep_bal', 'new_skill',
#        'fam_connect', 'relaxed', 'self_time', 'like_hw', 'dislike_hw',
#        'prefer', 'certaindays_hw', 'time_bp.1'],
#       dtype='object')

# %%
df['age'].unique()
# Out:
# array(['19-25', 'Dec-18', '33-40', '60+', '26-32', '40-50', '50-60'],
#       dtype=object)

# %%
age_mapping = {
    '19-25': 22,
    'Dec-18': 18,  
    '33-40': 36.5,
    '60+': 65,
    '26-32': 29,
    '40-50': 45,
    '50-60': 55
}

# %%
df['age'] = df['age'].map(age_mapping)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'occupation', 'time_bp', 'time_dp', 'travel_time',
#        'easeof_online', 'home_env', 'prod_inc', 'sleep_bal', 'new_skill',
#        'fam_connect', 'relaxed', 'self_time', 'like_hw', 'dislike_hw',
#        'prefer', 'certaindays_hw', 'time_bp.1'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1175 non-null   float64
#  1   gender          1175 non-null   object
#  2   occupation      1175 non-null   object
#  3   time_bp         1175 non-null   int64
#  4   time_dp         1175 non-null   int64
#  5   travel_time     1175 non-null   float64
#  6   easeof_online   1175 non-null   int64
#  7   home_env        1175 non-null   int64
#  8   prod_inc        1175 non-null   float64
#  9   sleep_bal       1175 non-null   float64
#  10  new_skill       1175 non-null   float64
#  11  fam_connect     1175 non-null   float64
#  12  relaxed         1175 non-null   float64
#  13  self_time       1175 non-null   float64
#  14  like_hw         1175 non-null   int64
#  15  dislike_hw      1175 non-null   int64
#  16  prefer          1175 non-null   object
# ...

# %%
change_columns = ['prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed', 'self_time']
df['lifestyle_change'] = df[change_columns].apply(lambda row: np.any(np.abs(row) > 0.5), axis=1).astype(int)

# %%
df['lifestyle_change'].unique()
# Out:
# array([1, 0])

# %%
df['lifestyle_change'].value_counts()
# Out:
# lifestyle_change
# 1    761
# 0    414
# Name: count, dtype: int64

# %%
# pip install --upgrade  scipy scikit-learn



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
numerical_transformer = StandardScaler()

# %%
df_numerical = pd.DataFrame(numerical_transformer.fit_transform(df[numerical_columns]), columns=numerical_columns)

# %%
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# %%
df_categorical = pd.get_dummies(df[object_columns], columns=object_columns)

# %%
df_preprocessed = pd.concat([df_numerical, df_categorical, df['lifestyle_change']], axis=1)

# %%
df_preprocessed.columns
# Out:
# Index(['time_bp', 'time_dp', 'travel_time', 'easeof_online', 'home_env',
#        'prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed',
#        'self_time', 'like_hw', 'dislike_hw', 'time_bp.1', 'age_18.0',
#        'age_22.0', 'age_29.0', 'age_36.5', 'age_45.0', 'age_55.0', 'age_65.0',
#        'gender_Female', 'gender_Male', 'gender_Prefer not to say',
#        'occupation_Currently Out of Work', 'occupation_Entrepreneur',
#        'occupation_Homemaker',
#        'occupation_Medical Professional aiding efforts against COVID-19',
#        'occupation_Retired/Senior Citizen', 'occupation_Student in College',
#        'occupation_Student in School', 'occupation_Working Professional',
#        'prefer_Complete Physical Attendance', 'prefer_Work/study from home',
#        'certaindays_hw_Maybe', 'certaindays_hw_No', 'certaindays_hw_Yes',
#        'lifestyle_change'],
#       dtype='object')

# %%
X = df_preprocessed.drop(columns='lifestyle_change')
y = df_preprocessed['lifestyle_change']

# %%
X.columns
# Out:
# Index(['time_bp', 'time_dp', 'travel_time', 'easeof_online', 'home_env',
#        'prod_inc', 'sleep_bal', 'new_skill', 'fam_connect', 'relaxed',
#        'self_time', 'like_hw', 'dislike_hw', 'time_bp.1', 'age_18.0',
#        'age_22.0', 'age_29.0', 'age_36.5', 'age_45.0', 'age_55.0', 'age_65.0',
#        'gender_Female', 'gender_Male', 'gender_Prefer not to say',
#        'occupation_Currently Out of Work', 'occupation_Entrepreneur',
#        'occupation_Homemaker',
#        'occupation_Medical Professional aiding efforts against COVID-19',
#        'occupation_Retired/Senior Citizen', 'occupation_Student in College',
#        'occupation_Student in School', 'occupation_Working Professional',
#        'prefer_Complete Physical Attendance', 'prefer_Work/study from home',
#        'certaindays_hw_Maybe', 'certaindays_hw_No', 'certaindays_hw_Yes'],
#       dtype='object')

# %%
X.to_csv('covid_preprocessed_data.csv', index=False)

# %%
X
# Out:
#        time_bp   time_dp  travel_time  easeof_online  home_env  prod_inc  \
# 0    -0.207190 -1.118996    -0.740045       0.368080  0.200490 -0.014535
# 1    -0.207190  1.140145    -0.740045       1.157303 -0.609048 -0.827779
# 2    -0.207190 -0.365949     0.662459      -0.421143 -0.609048  1.611954
# 3    -0.207190 -0.365949     0.662459       0.368080 -1.418586 -0.014535
# 4    -0.207190 -0.365949     0.662459      -0.421143 -0.609048 -0.014535
# ...        ...       ...          ...            ...       ...       ...
# 1170  0.790549  0.387098    -0.740045      -0.421143 -1.418586  0.798710
# 1171 -1.204929  1.516669    -0.740045       0.368080  1.819565 -0.827779
# 1172  0.790549  1.140145    -0.740045       0.368080 -0.609048  0.798710
# 1173  1.788288  1.516669     0.662459      -0.421143 -0.609048 -0.014535
# 1174 -1.204929 -1.118996    -0.740045      -0.421143 -0.609048  0.798710
#
#       sleep_bal  new_skill  fam_connect   relaxed  ...  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = y, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((940, 37), (235, 37))

# %%
y_train.shape, y_test.shape
# Out:
# ((940,), (235,))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.3.0

# %%
model_dt = DecisionTreeClassifier()

# %%
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model_dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_dt = accuracy_score(y_test, y_pred)

# %%
print("Accuracy: ", accuracy_dt * 100)
print("\nClassification Report: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  99.57446808510639
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        83
#            1       0.99      1.00      1.00       152
#
#     accuracy                           1.00       235
#    macro avg       1.00      0.99      1.00       235
# weighted avg       1.00      1.00      1.00       235

# %%
import pickle

# %%
filename = 'decision_tree_model_covid.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model_dt, file)
